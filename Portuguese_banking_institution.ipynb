# %% [markdown]
# # importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # load data

# %%
data=pd.read_csv(r"C:\Users\Arbaj\Downloads\bank-full.csv\bank-full.csv",sep=";")
data
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
data.shape
# Out:
# (45211, 17)

# %%
data.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
data.rename(columns={'y':'target'},inplace=True)
data.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome target
# 0  unknown    5   may       261         1     -1         0  unknown     no
# 1  unknown    5   may       151         1     -1         0  unknown     no
# 2  unknown    5   may        76         1     -1         0  unknown     no
# 3  unknown    5   may        92         1     -1         0  unknown     no
# 4  unknown    5   may       198         1     -1         0  unknown     no

# %%
data[data.age<=0]
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, balance, housing, loan, contact, day, month, duration, campaign, pdays, previous, poutcome, target]
# Index: []

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(20,5))
sns.histplot(data.age,kde=True)
plt.show()
plt.figure(figsize=(20,5))
sns.boxplot(data.age)
plt.show()
# Out:
# C:\Users\Arbaj\anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(20,10))
sns.countplot(data.age,palette='Set1')
plt.title('AGE DISTRIBUTION')
# Out:
# C:\Users\Arbaj\anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'AGE DISTRIBUTION')

# %%
from collections import Counter
for i in data.columns:
    plt.figure(figsize=(20,8))
    sns.countplot(data[i],palette="Set1")
    plt.title(f'{i} distribution')
    plt.show()
    if len(Counter(data[i]))<15:
        
        print(Counter(data[i]))
# Out:
# C:\Users\Arbaj\anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Arbaj\anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Counter({'blue-collar': 9732, 'management': 9458, 'technician': 7597, 'admin.': 5171, 'services': 4154, 'retired': 2264, 'self-employed': 1579, 'entrepreneur': 1487, 'unemployed': 1303, 'housemaid': 1240, 'student': 938, 'unknown': 288})
# ...

# %%
sns.pairplot(data,hue='target')

# %%
np.percentile(data.age,75)
# Out:
# 48.0

# %%
for i in data.columns:
    if data[i].dtypes=='int64':
        fig,axes=plt.subplots(1,2,figsize=(20,8))
        
        sns.boxplot(data[i],ax=axes[0])
        
        
        sns.histplot(data[i],kde=True,ax=axes[1])
        q3=np.percentile(data[i],75)
        q1=np.percentile(data[i],25)
        iqr=q3-q1
        maxi=q3+(1.5*iqr)
        mini=q1-(1.5*iqr)
        
        plt.title(f'{i}')
        plt.show()
        print(f"min:{mini}       max:{maxi}")
# Out:
# C:\Users\Arbaj\anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# min:10.5       max:70.5
# C:\Users\Arbaj\anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# min:-1962.0       max:3462.0
# ...

# %%
data['target']=data['target'].map({'yes':1,'no':0})
data.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome  target
# 0  unknown    5   may       261         1     -1         0  unknown       0
# 1  unknown    5   may       151         1     -1         0  unknown       0
# 2  unknown    5   may        76         1     -1         0  unknown       0
# 3  unknown    5   may        92         1     -1         0  unknown       0
# 4  unknown    5   may       198         1     -1         0  unknown       0

# %%
pip install --upgrade category_encoders
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.2.2; however, version 22.3.1 is available.
# You should consider upgrading via the 'C:\Users\Arbaj\anaconda3\envs\tensorflow\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# # FEATURE ENGINEERING

# %%
import category_encoders as ce
cols=['job','marital','education','default','housing','loan','contact','month','duration','poutcome']
encoder=ce.OrdinalEncoder(cols)

# %%
X=data.drop('target',axis=1)
Y=data.target.values

# %%
X1=encoder.fit_transform(X)
X1
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       58    1        1          1        1     2143        1     1        1
# 1       44    2        2          2        1       29        1     1        1
# 2       33    3        1          2        1        2        1     2        1
# 3       47    4        1          3        1     1506        1     1        1
# 4       33    5        2          3        1        1        2     1        1
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45206   51    2        1          1        1      825        2     1        2
# 45207   71    6        3          4        1     1729        2     1        2
# 45208   72    6        1          2        1     5715        2     1        2
# 45209   57    4        1          2        1      668        2     1        3
# 45210   37    3        1          2        1     2971        2     1        2
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
mmc=MinMaxScaler()
X1['balance']=mmc.fit_transform(X1[['balance']])
X1
# Out:
#        age  job  marital  education  default   balance  housing  loan  \
# 0       58    1        1          1        1  0.092259        1     1
# 1       44    2        2          2        1  0.073067        1     1
# 2       33    3        1          2        1  0.072822        1     2
# 3       47    4        1          3        1  0.086476        1     1
# 4       33    5        2          3        1  0.072812        2     1
# ...    ...  ...      ...        ...      ...       ...      ...   ...
# 45206   51    2        1          1        1  0.080293        2     1
# 45207   71    6        3          4        1  0.088501        2     1
# 45208   72    6        1          2        1  0.124689        2     1
# 45209   57    4        1          2        1  0.078868        2     1
# 45210   37    3        1          2        1  0.099777        2     1
#
#        contact  day  month  duration  campaign  pdays  previous  poutcome
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X1,Y)

# %%
print("elements in X_train :",X_train.shape)
print("elements in  X_test :",X_test.shape)
print("elements in Y_train :",y_train.shape)
print("elements in Y_test :",y_test.shape)
# Out:
# elements in X_train : (33908, 16)
# elements in  X_test : (11303, 16)
# elements in Y_train : (33908,)
# elements in Y_test : (11303,)

# %% [markdown]
# # MODEL IMPORTING

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,confusion_matrix,classification_report
from sklearn.ensemble import RandomForestClassifier
RF=RandomForestClassifier()
RF.fit(X_train,y_train)
y_pred=RF.predict(X_test)
Accuracy=accuracy_score(y_test,y_pred)
conf=confusion_matrix(y_test,y_pred)
report=classification_report(y_test,y_pred)

# %%
print(f"Accuracy score of Random forest Algorithm is {Accuracy*100} %")
print(f"Confusion MAtrix :\n {conf} ")
print(f"Classification  report is as follows :\n {report} ")
# Out:
# Accuracy score of Random forest Algorithm is 90.31230646730957 %
# Confusion MAtrix :
#  [[9616  310]
#  [ 785  592]]
# Classification  report is as follows :
#                precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95      9926
#            1       0.66      0.43      0.52      1377
#
#     accuracy                           0.90     11303
#    macro avg       0.79      0.70      0.73     11303
# weighted avg       0.89      0.90      0.89     11303

# %% [markdown]
# # SOLVING IMBALANCE DATA ISSUE

# %%
data.target.value_counts()
# Out:
# 0    39922
# 1     5289
# Name: target, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 2)
X_train1, y_train1 = sm.fit_resample(X_train, y_train.ravel())

# %%
print(sum(y_train==0),sum(y_train==1))
# Out:
# 29996 3912

# %%
print(sum(y_train1==0),sum(y_train1==1))
# Out:
# 29996 29996

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,confusion_matrix,classification_report
from sklearn.ensemble import RandomForestClassifier
RF=RandomForestClassifier()
RF.fit(X_train1,y_train1)
y_pred=RF.predict(X_test)
Accuracy=accuracy_score(y_test,y_pred)
conf=confusion_matrix(y_test,y_pred)
report=classification_report(y_test,y_pred)

# %%
print(f"Accuracy score of Random forest Algorithm is {Accuracy*100} %")
print(f"Confusion MAtrix :\n {conf} ")
print(f"Classification  report is as follows :\n {report} ")
# Out:
# Accuracy score of Random forest Algorithm is 88.02087941254534 %
# Confusion MAtrix :
#  [[9002  924]
#  [ 430  947]]
# Classification  report is as follows :
#                precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93      9926
#            1       0.51      0.69      0.58      1377
#
#     accuracy                           0.88     11303
#    macro avg       0.73      0.80      0.76     11303
# weighted avg       0.90      0.88      0.89     11303

# %% [markdown]
# # TRYING DIFFERENT MODELS

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso,LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.cluster import KMeans,DBSCAN
from sklearn.naive_bayes import GaussianNB,BernoulliNB,MultinomialNB
from sklearn.decomposition import PCA,LatentDirichletAllocation

A=LinearRegression()
B=Ridge()
C=Lasso()
D=LogisticRegression()
E=SVC()
F=KNeighborsClassifier()
G=DecisionTreeClassifier()
H=RandomForestClassifier()
I=KMeans()
J=DBSCAN()
K=GaussianNB()
L=BernoulliNB()
M=MultinomialNB()
N=PCA()
O=LatentDirichletAllocation()

models=[A,B,C,I,N]
models

model_names=[]
accuracy_model=[]
for i in models:
    accuracy=i.fit(X_train1,y_train1)
    score=accuracy.score(X_test,y_test)
    accuracy_model.append('%s=%.2f'%(i,score))
    
accuracy_model
# Out:
# ['LinearRegression()=-0.40',
#  'Ridge()=-0.40',
#  'Lasso()=-0.63',
#  'KMeans()=-94916401.83',
#  'PCA()=-33.65']

# %% [markdown]
# # USING ANN

# %%
X_train1.shape
# Out:
# (59992, 16)

# %%
X_train.shape
# Out:
# (33908, 16)

# %%
y_train1.shape
# Out:
# (59992,)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras





model1 = keras.Sequential([
    keras.layers.Flatten(input_shape=[16]),
    keras.layers.Dense(100000,activation='relu'),
    keras.layers.Dense(100,activation='relu'),
    keras.layers.Dense(100,activation='relu'),
    keras.layers.Dense(100,activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')
])
model1.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model1.fit(X_train1,y_train1,epochs=5)
model1.summary
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 14s 7ms/step - loss: nan - accuracy: 0.5000
# Epoch 2/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: nan - accuracy: 0.5000
# Epoch 3/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: nan - accuracy: 0.5000
# Epoch 4/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: nan - accuracy: 0.5000
# Epoch 5/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: nan - accuracy: 0.5000
# <bound method Model.summary of <keras.engine.sequential.Sequential object at 0x000001425141F070>>

# %%
model1.evaluate(X_test,y_test)
# Out:
# 354/354 [==============================] - 1s 3ms/step - loss: nan - accuracy: 0.8782
# [nan, 0.8781739473342896]

# %%
pred1=model1.predict(X_test)
pred2=[np.argmax(i)for i in pred1]
pred2[1254]
# Out:
# 354/354 [==============================] - 1s 2ms/step
# 0

# %%
Accuracy=accuracy_score(y_test,pred2)
conf=confusion_matrix(y_test,pred2)
report=classification_report(y_test,pred2)
# Out:
# C:\Users\Arbaj\anaconda3\envs\tensorflow\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Arbaj\anaconda3\envs\tensorflow\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Arbaj\anaconda3\envs\tensorflow\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
print(f"Accuracy score of ANN Algorithm is {Accuracy*100} %")
print(f"Confusion MAtrix :\n {conf} ")
print(f"Classification  report is as follows :\n {report} ")
# Out:
# Accuracy score of ANN Algorithm is 87.81739361231531 %
# Confusion MAtrix :
#  [[9926    0]
#  [1377    0]]
# Classification  report is as follows :
#                precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      9926
#            1       0.00      0.00      0.00      1377
#
#     accuracy                           0.88     11303
#    macro avg       0.44      0.50      0.47     11303
# weighted avg       0.77      0.88      0.82     11303

# %% [markdown]
# # MODEL CREATED USING BALANCED DATA SET IS BETTER THAN OTHOTHER
